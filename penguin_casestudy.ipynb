# %% [markdown]
# <a href="https://colab.research.google.com/github/ahsal075/ahsal/blob/main/penguin_casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
penguin_df = sns.load_dataset('penguins')
penguin_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguin_df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
penguin_df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
penguin_df['sex'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
penguin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguin_df.size
# Out:
# 2408

# %%
penguin_df.shape
# Out:
# (344, 7)

# %%
penguin_df.columns.to_list()
# Out:
# ['species',
#  'island',
#  'bill_length_mm',
#  'bill_depth_mm',
#  'flipper_length_mm',
#  'body_mass_g',
#  'sex']

# %%
penguin_df.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
cleaned_penguin_df = penguin_df.dropna()
cleaned_penguin_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
cleaned_penguin_df.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
sns.scatterplot(data = cleaned_penguin_df, x="flipper_length_mm", y="body_mass_g",hue='island')
plt.title("Flipper Length vs Body Mass")
plt.show()

# %%
sns.pairplot(data=cleaned_penguin_df,hue='species')
plt.suptitle("Pair Plot of Penguin Features", y=1.02)
plt.show()

# %%
sns.histplot(data=cleaned_penguin_df, x="body_mass_g", hue="species", kde=True)
plt.title("Body Mass Distribution")
plt.show()

# %%
sns.boxplot(data=cleaned_penguin_df, x="species", y="body_mass_g", hue="sex")
plt.title("Boxplot of Body Mass by Species and Sex")
plt.show()

# %%
sns.violinplot(data=cleaned_penguin_df, x="species", y="flipper_length_mm", hue="sex", split=True)
plt.title("Violin Plot of Flipper Length by Species and Sex")
plt.show()

# %%
sns.barplot(data=cleaned_penguin_df, x="island", y="bill_length_mm")
plt.title("Average Bill Length per Island")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=cleaned_penguin_df, x="species", hue="sex")
plt.title("Number of Penguins by Species and Sex")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=cleaned_penguin_df, x="species", hue="island")
plt.title("Number of Penguins by Species and Island")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.stripplot(data=cleaned_penguin_df, x="species", y="body_mass_g", hue="sex")
plt.title("Body Mass by Species and Sex")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.swarmplot(data=cleaned_penguin_df, x="species", y="bill_length_mm", hue="sex")
plt.title("Bill Length by Species and Sex")
plt.show()

# %% [markdown]
# INSIGHTS
#
# Male penguins are heavier than female penguins.
#
# Male penguins have longer flippers than females.
#
# Gentoo male penguins are the heaviest.
#
# Adelie penguins live on all three islands.
#
# Chinstrap penguins live only on Dream Island.
#
# Gentoo penguins live only on Biscoe Island.
